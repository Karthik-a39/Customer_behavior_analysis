# %%
import pandas as pd
import numpy as np

data=pd.read_csv("../csv-files/customer_shopping_behavior.csv");
data.head(5)
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
data.info()
data.isnull().sum()

data['Review Rating'] = data['Review Rating'].fillna(
    data.groupby('Category')['Review Rating'].transform('median')
)
print(data.isnull().sum())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   str
#  3   Item Purchased          3900 non-null   str
#  4   Category                3900 non-null   str
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   str
#  7   Size                    3900 non-null   str
#  8   Color                   3900 non-null   str
#  9   Season                  3900 non-null   str
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   str
#  12  Shipping Type           3900 non-null   str
#  13  Discount Applied        3900 non-null   str
#  14  Promo Code Used         3900 non-null   str
# ...

# %%
#making columns as lowercase and replacing space with underscore
data.columns=data.columns.str.lower()
data.columns=data.columns.str.replace(' ','_')
data=data.rename(columns={'purchase_amount_(usd)':'purchase_amount'})
data.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='str')

# %%
#create a column for age_group

labels=['Young Adult','Adult','Middle-aged','Senior']
data['age_group']=pd.qcut(data['age'],q=4,labels=labels)
data[['age','age_group']].head(10)
# Out:
#    age    age_group
# 0   55  Middle-aged
# 1   19  Young Adult
# 2   50  Middle-aged
# 3   21  Young Adult
# 4   45  Middle-aged
# 5   46  Middle-aged
# 6   63       Senior
# 7   27  Young Adult
# 8   26  Young Adult
# 9   57  Middle-aged

# %%
#create column purchase_frequency_days

frequent_mapping={
    'Fortnightly':14,
    'Weekly':10,
    'Monthly':30,
    'Quarterly':90,
    'Bi-Weekly':14,
    'Annually':365,
    'Every 3 Months':90
}
data['purchase_frequent_days']=data['frequency_of_purchases'].map(frequent_mapping)
data[['frequency_of_purchases','purchase_frequent_days']].head(10)
# Out:
#   frequency_of_purchases  purchase_frequent_days
# 0            Fortnightly                      14
# 1            Fortnightly                      14
# 2                 Weekly                      10
# 3                 Weekly                      10
# 4               Annually                     365
# 5                 Weekly                      10
# 6              Quarterly                      90
# 7                 Weekly                      10
# 8               Annually                     365
# 9              Quarterly                      90

# %%
#promo_code_used and discount_appilend have same values
# (data['discount_applied']==data['promo_code_used']).all()
# data=data.drop('promo_code_used',axis=1)
# data.columns
data.to_csv('cleaned_customer_shopping.csv',index=False)

# %%
from sqlalchemy import create_engine

# MySQL connection
engine = create_engine("mysql+mysqlconnector://root:Karthik%4020@localhost:3306/customer_analysis")
cleaned_data=pd.read_csv('../csv-files/cleaned_customer_shopping.csv')
cleaned_data.to_sql(name='customer_shopping_behaviour', con=engine, if_exists='replace', index=False)
# Out:
# Traceback (most recent call last):
#
#   File ~\AppData\Roaming\Python\Python314\site-packages\IPython\core\interactiveshell.py:3701 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[25], line 4
#     engine = create_engine("mysql+mysqlconnector://root:Karthik@20@localhost:3306/customer_analysis")
#
#   File <string>:2 in create_engine
#
#   File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\util\deprecations.py:281 in warned
#     return fn(*args, **kwargs)  # type: ignore[no-any-return]
#
#   File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\engine\create.py:617 in create_engine
#     dbapi = dbapi_meth(**dbapi_args)
#
#   File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\dialects\mysql\mysqlconnector.py:165 in import_dbapi
#     return cast("DBAPIModule", __import__("mysql.connector").connector)
#
#   File <string>
#
# SyntaxError: source code string cannot contain null bytes
